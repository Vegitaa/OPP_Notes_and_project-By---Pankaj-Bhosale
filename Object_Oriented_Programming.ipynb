# %% [markdown]
# <a href="https://colab.research.google.com/github/Vegitaa/OPP_Notes_and_project-By---Pankaj-Bhosale/blob/main/Object_Oriented_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OBJECT ORIENTED PROGRAMMING (OOP)- Pankaj Bhosale
#  Application of oop
#
#  1- Genenrality to Specificity
#
#  2-you can create as a programmer your own data type
#
#  3-Suitable for real life application to solve real life problem
#
#  4-different way of programming

# %% [markdown]
# ![Screenshot 2024-05-14 at 5.08.56 PM.png](data:image/png;base64,...)

# %% [markdown]
# # 1-Class
# **defination:- "Blue print of how a object will behave"**
#
# obejects are always belongs to some class.
#
# ng the class of it like blue print
# in simple words
# *data type == class == when you create a varible of it it's called Object *
#
# for Eg-

# %%
a=5

# %%
type(a)# "a " is object which belongs to integer class
# Out:
# int

# %% [markdown]
# ![Screenshot 2024-05-14 at 5.24.13 PM.png](data:image/png;base64,...)

# %% [markdown]
# If you are building the class object car then
#
# 1.data or property related it would be NO. of wheels,colour, engine-type etc.
#
# 2.Function would be calculate speed,open air bag,gps navigation.

# %%
# basic Structure of class

'''
class Car:

  colur ="Blue" # data

  Model="sports" # data

  def calcute_Avg_speed(km,time):

    #some code '''
# Out:
# '\nclass Car:\n\n  colur ="Blue" # data\n\n  Model="sports" # data\n\n  def calcute_Avg_speed(km,time):\n\n    #some code '

# %% [markdown]
# Class Name should be in Pascal case
#
# ThisIsPascalCase

# %% [markdown]
# Representation of Class
#
# ![Screenshot 2024-05-14 at 5.40.58 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Object
#
# Object is an instance of class
# examples of objects are
#
# 1.Car---------->Harrier  // Harrier=Car()
#
# 2.Sports------->cricket //  cricket=Sports()
#
# 3.Animal------->cat     //  cat=Animal()

# %%
L=[1,2,3,4] #Object litral

# %%
L
# Out:
# [1, 2, 3, 4]

# %%
L=list()
L
# Out:
# []

# %%
city=str()
city
# Out:
# ''

# %% [markdown]
# # Function Vs Methods
#
# 1.Methods are basically function which is written inside a class
#
# Function is a Normal function which is not written inside of a class(it is used as gloabally )

# %%
len(L)# Fucntion is available for other things also like string, interger
# Out:
# 0

# %%
L.append(2) # method is only used by the object of that class # in this case append is only used for list class

# %% [markdown]
# # why is there need for self or what is mean by self?
#
# Object oriented programming fundamental concept
#
#
#
# 1. In class there are Data and Functions are they are only acceceble by Object
#
# 2. In class a method of its own can not access the another method with in same class
#
# 3. Thats why we use 'self' which is the object creted to acess the methods with in self class "self"=="Object"

# %%
'''class ATM:
# Constructor
# Special methods/Magic methods/Dunder Menthods

# Object can_not call magic method it calls itself by default .

  def __init__(self):


    self.pin='' # instance variable
    self.balance=0 # value of instance variable is diffrent for each


    self.menu()


  def menu(self):       #Method

    user_input=input(

        Hello how would you like to pocecced?
        1.Enter 1 to Create pin
        2.Enter 2 to deposit
        3.Enter 3 to withdraw
        4.Enter 4 to check Balance
        5.Enter 5 to exit




    )


    if user_input=='1':
     self.create_pin()
    elif user_input=='2':
      self.deposit()
    elif user_input=='3':
     self.withdraw()
    elif user_input=='4':
     self.check_balance()
    else:
      print('bye')

  def create_pin(self):                   # create pin method
    self.pin=input('Enter your pin ')
    print('Pin set Successfully')

  def deposit(self):                      # deposit method
    temp=input('Enter your pin')
    if temp==self.pin:
      amount=int(input('Enter the Amount'))
      self.balance=self.balance + amount
      print('Deposit Successful')
    else:
      print('Invalid Pin')

  def withdraw(self):                         #''
     temp=input('Enter your pin')
     if temp==self.pin:
        amount=int(input('Enter the Amount'))
        if amount< self.balance :
              self.balance=self.balance-amount
              print('Opration Successful')
        else:
              print('insufficient funds')
     else:
      print('invalid pin')

  def check_balance(self):                 #''
     temp=input('Enter your pin')
     if temp==self.pin:
      print(self.balance)

     else:
      print("invalid pin ")'''
# Out:
# 'class ATM:\n# Constructor\n# Special methods/Magic methods/Dunder Menthods\n\n# Object can_not call magic method it calls itself by default .\n\n  def __init__(self):\n\n\n    self.pin=\'\' # instance variable\n    self.balance=0 # value of instance variable is diffrent for each\n\n\n    self.menu()\n\n\n  def menu(self):       #Method\n\n    user_input=input(\n       \n        Hello how would you like to pocecced?\n        1.Enter 1 to Create pin\n        2.Enter 2 to deposit\n        3.Enter 3 to withdraw\n        4.Enter 4 to check Balance\n        5.Enter 5 to exit\n\n\n\n       \n    )\n\n\n    if user_input==\'1\':\n     self.create_pin()\n    elif user_input==\'2\':\n      self.deposit()\n    elif user_input==\'3\':\n     self.withdraw()\n    elif user_input==\'4\':\n     self.check_balance()\n    else:\n      print(\'bye\')\n\n  def create_pin(self):                   # create pin method\n    self.pin=input(\'Enter your pin \')\n    print(\'Pin set Successfully\')\n\n  def d
# ...

# %%
#sbi=ATM()

# %%
#sbi.check_balance()

# %%
#sbi.deposit()

# %%
#sbi.check_balance()

# %%
#sbi.withdraw()

# %%
#sbi.check_balance()

# %%
class Fraction :


  def __init__(self,n,d):

   self.num=n # instance variable
   self.den=d


  def __str__(self):
   return "{}/{}".format(self.num,self.den)


  def __add__(self,other):
   temp_num= self.num *other.den + other.num * self.den
   temp_den=self.den * other.den

   return "{}/{}".format(temp_num,temp_den)


  def __sub__(self,other):
   temp_num= self.num *other.den - other.num * self.den
   temp_den=self.den * other.den

   return "{}/{}".format(temp_num,temp_den)

  def __mul__(self,other):
   temp_num=self.num * other.num
   temp_den=self.num * other.den

   return "{}/{}".format(temp_num,temp_den)

  def __truediv__(self,other):

   temp_num =self.num *other.den
   temp_den =self.den *other.num
   return "{}/{}".format(temp_num,temp_den)

# %%
x=Fraction(5,5)

# %%
y=Fraction(6,6)

# %%
print(x)
# Out:
# 5/5

# %%
print(y)
# Out:
# 6/6

# %%
print(x+y)
# Out:
# 60/30

# %%
print(x-y)
# Out:
# 0/30

# %%
print(x*y)
# Out:
# 30/30

# %%
print(x/y)
# Out:
# 30/30

# %% [markdown]
# # 2. Encapsulation
# 1. What is Encapsualtion ?
#
# Encapsulation is used to restrict access of data members and functions in a class.
#
# 2.   Need for Encapsulation
# while making a class there can be some varibales which should be kept private
# these type of variable uses "__" for makeking them private.
#
# but in python there is no such thing called truly private
#
# so comes the 2 methods  Getter and Setter methods to access and edit the
# variable for another use

# %%
'''class ATM:
# Constructor
# Special methods/Magic methods/Dunder Menthods

# Object can_not call magic method it calls itself by default .

  def __init__(self):


    self.pin='' # instance variable
    self.balance=0 # value of instance variable is diffrent for each class


    self.menu()


  def menu(self):       #Method

    user_input=input(
        '''
        Hello how would you like to pocecced?
        1.Enter 1 to Create pin
        2.Enter 2 to deposit
        3.Enter 3 to withdraw
        4.Enter 4 to check Balance
        5.Enter 5 to exit



       '''
    )


    if user_input=='1':
     self.create_pin()
    elif user_input=='2':
      self.deposit()
    elif user_input=='3':
     self.withdraw()
    elif user_input=='4':
     self.check_balance()
    else:
      print('bye')

  def create_pin(self):                   # create pin method
    self.pin=input('Enter your pin ')
    print('Pin set Successfully')

  def deposit(self):                      # deposit method
    temp=input('Enter your pin')
    if temp==self.pin:
      amount=int(input('Enter the Amount'))
      self.balance=self.balance + amount
      print('Deposit Successful')
    else:
      print('Invalid Pin')

  def withdraw(self):                         #''
     temp=input('Enter your pin')
     if temp==self.pin:
        amount=int(input('Enter the Amount'))
        if amount< self.balance :
              self.balance=self.balance-amount
              print('Opration Successful')
        else:
              print('insufficient funds')
     else:
      print('invalid pin')

  def check_balance(self):                 #''
     temp=input('Enter your pin')
     if temp==self.pin:
      print(self.balance)

     else:
      print("invalid pin ")'''

# %%
# HDFC=ATM()

# %%
# HDFC.balance

# %%
# HDFC.balance="pankaj"# ------> anyone can access it so solution is by using __ you can make them private...

# %%
# HDFC.deposit()

# %%
class ATM:
# Constructor
# Special methods/Magic methods/Dunder Menthods

# Object can_not call magic method it calls itself by default .

  def __init__(self):


    self.__pin='' # instance variable
    self.__balance=0 # value of instance variable is different for each class


    self.menu()


  def menu(self):       #Method

    user_input=input(
        '''
        Hello how would you like to pocecced?
        1.Enter 1 to Create pin
        2.Enter 2 to deposit
        3.Enter 3 to withdraw
        4.Enter 4 to check Balance
        5.Enter 5 to exit



       '''
    )


    if user_input=='1':
     self.create_pin()
    elif user_input=='2':
      self.deposit()
    elif user_input=='3':
     self.withdraw()
    elif user_input=='4':
     self.check_balance()
    else:
      print('bye')

  def create_pin(self):                   # create pin method
    self.__pin=input('Enter your pin ')
    print('Pin set Successfully')

  def deposit(self):                      # deposit method
    temp=input('Enter your pin')
    if temp==self.__pin:
      amount=int(input('Enter the Amount'))
      self.__balance=self.__balance + amount
      print('Deposit Successful')
    else:
      print('Invalid Pin')

  def withdraw(self):                         #''
     temp=input('Enter your pin')
     if temp==self.__pin:
        amount=int(input('Enter the Amount'))
        if amount< self.__balance :
              self.__balance=self.__balance-amount
              print('Opration Successful')
        else:
              print('insufficient funds')
     else:
      print('invalid pin')

  def check_balance(self):                 #''
     temp=input('Enter your pin')
     if temp==self.__pin:
      print(self.__balance)

     else:
      print("invalid pin ")

# %%
HDFC=ATM()
# Out:
#         Hello how would you like to pocecced?
#         1.Enter 1 to Create pin
#         2.Enter 2 to deposit
#         3.Enter 3 to withdraw
#         4.Enter 4 to check Balance
#         5.Enter 5 to exit
#
#
#
#        1
# Enter your pin 12345
# Pin set Successfully

# %%
HDFC.create_pin()

# %% [markdown]
# ![Screenshot 2024-05-15 at 3.20.05 PM.png](data:image/png;base64,...)

# %% [markdown]
# Now Only Methods are visible    # used "__" for hide it

# %%
HDFC=ATM()
# Out:
#         Hello how would you like to pocecced?
#         1.Enter 1 to Create pin
#         2.Enter 2 to deposit
#         3.Enter 3 to withdraw
#         4.Enter 4 to check Balance
#         5.Enter 5 to exit
#
#
#
#        1
# Enter your pin 2345
# Pin set Successfully

# %%
HDFC.__balance='slsjj'

# %%
HDFC.deposit()
# Out:
# Enter your pin2345
# Enter the Amount1000
# Deposit Successful

# %%
HDFC.check_balance()
# Out:
# Enter your pin2345
# 2000

# %%
HDFC._ATM__balance="sjajksjc"

# %%
# HDFC.deposit() #will through an error

# %% [markdown]
# *TO overcome this![Screenshot 2024-05-15 at 4.41.19 PM.png](data:image/png;base64,...)*

# %%
class ATM:
# Constructor
# Special methods/Magic methods/Dunder Menthods

# Object can_not call magic method it calls itself by default .

  def __init__(self):


    self.__pin='' # instance variable
    self.__balance=0 # value of instance variable is different for each class


    self.menu()

  def get_pin(self):
      return self.__pin


  def set_pin(self,new_pin):
    if type(new_pin)==str:
      self.__pin=new_pin
      print(' Pin changed ')

    else:
      print(' Not Allowed ! ')



  def menu(self):       #Method

    user_input=input(
        '''
        Hello how would you like to pocecced?
        1.Enter 1 to Create pin
        2.Enter 2 to deposit
        3.Enter 3 to withdraw
        4.Enter 4 to check Balance
        5.Enter 5 to exit



       '''
    )


    if user_input=='1':
     self.create_pin()
    elif user_input=='2':
      self.deposit()
    elif user_input=='3':
     self.withdraw()
    elif user_input=='4':
     self.check_balance()
    else:
      print('bye')

  def create_pin(self):                   # create pin method
    self.__pin=input('Enter your pin ')
    print('Pin set Successfully')

  def deposit(self):                      # deposit method
    temp=input('Enter your pin')
    if temp==self.__pin:
      amount=int(input('Enter the Amount'))
      self.__balance=self.__balance + amount
      print('Deposit Successful')
    else:
      print('Invalid Pin')

  def withdraw(self):                         #''
     temp=input('Enter your pin')
     if temp==self.__pin:
        amount=int(input('Enter the Amount'))
        if amount< self.__balance :
              self.__balance=self.__balance-amount
              print('Opration Successful')
        else:
              print('insufficient funds')
     else:
      print('invalid pin')

  def check_balance(self):                 #''
     temp=input('Enter your pin')
     if temp==self.__pin:
      print(self.__balance)

     else:
      print("invalid pin ")

# %%
sbi=ATM()
# Out:
#         Hello how would you like to pocecced?
#         1.Enter 1 to Create pin
#         2.Enter 2 to deposit
#         3.Enter 3 to withdraw
#         4.Enter 4 to check Balance
#         5.Enter 5 to exit
#
#
#
#        1
# Enter your pin 1234
# Pin set Successfully

# %%
sbi.set_pin('www')# added setter
# Out:
#  Pin changed

# %%
sbi.get_pin() # added getter
# Out:
# 'www'

# %% [markdown]
# ### points to Remember
#
# 1. Reference Variable
#
# in above we have write oject like "sbi=ATM()" which means "ATM()" is an
#
# actual object which is stored in the variable name "sbi".
#
#
# 2. pass by reference
# using pass reference if you are passsing a mutable object to a function then that will change your original data and if you are passing immutable data to it then it will not change the original.
#
# for example :-

# %%
def change(L):
  print(id(L))

  L=L.append(5)

  print(id(L))


L1=[1,2,3,4,5]
print(id(L1))
print(L1)

change(L1)


print(L1)
# Out:
# 137860779574144
# [1, 2, 3, 4, 5]
# 137860779574144
# 96358759142368
# [1, 2, 3, 4, 5, 5]

# %%
def changed(L):
  print(id(L))
  L=L+(5,6)
  print(id(L))

L1=(1,2,3,4,5)

print(id(L1))
print(L1)


changed(L1)

print(L1)
# Out:
# 137861210973872
# (1, 2, 3, 4, 5)
# 137861210973872
# 137860779729216
# (1, 2, 3, 4, 5)

# %% [markdown]
# ### collection of object

# %%
class Customer():
 def __init__(self,name,age):
   self.name=name
   self.age=age

c1=Customer('pankaj',23)
c2=Customer('Abhi',23)
c3=Customer('tanu',21)

L=[c1,c2,c3]
for i in L:
  print(i.age,i.name)
# Out:
# 23 pankaj
# 23 Abhi
# 21 tanu

# %% [markdown]
# ### static method
# @static method
# There can be some functionality that relates to the class, but does not require any instance(s) to do some work, static methods can be used in such cases. A static method is a method which is bound to the class and not the object of the class. It can’t access or modify class state. It is present in a class because it makes sense for the method to be present in class. A static method does not receive an implicit first argument.
#
# static menthod can be accesable without object
#
# used when you are dealing with the static variable

# %%
class ATM:
# Constructor
# Special methods/Magic methods/Dunder Menthods

# Object can_not call magic method it calls itself by default .
#



# Static variable /Class
  __counter=1


  def __init__(self):


    self.__pin='' # instance variable
    self.__balance=0 # value of instance variable is different for each class
    self.sno=ATM.__counter
    ATM.__counter=ATM.__counter+1

    self.menu()



  def get_counter():
    return ATM.__counter

  def set_counter(new):
    if type(new)==int :
      ATM.__counter = new

    else:
      print('not allowed')






  def get_pin(self):
      return self.__pin


  def set_pin(self,new_pin):
    if type(new_pin)==str:
      self.__pin=new_pin
      print(' Pin changed ')

    else:
      print(' Not Allowed ! ')



  def menu(self):       #Method

    user_input=input(
        '''
        Hello how would you like to pocecced?
        1.Enter 1 to Create pin
        2.Enter 2 to deposit
        3.Enter 3 to withdraw
        4.Enter 4 to check Balance
        5.Enter 5 to exit



       '''
    )


    if user_input=='1':
     self.create_pin()
    elif user_input=='2':
      self.deposit()
    elif user_input=='3':
     self.withdraw()
    elif user_input=='4':
     self.check_balance()
    else:
      print('bye')

  def create_pin(self):                   # create pin method
    self.__pin=input('Enter your pin ')
    print('Pin set Successfully')

  def deposit(self):                      # deposit method
    temp=input('Enter your pin')
    if temp==self.__pin:
      amount=int(input('Enter the Amount'))
      self.__balance=self.__balance + amount
      print('Deposit Successful')
    else:
      print('Invalid Pin')

  def withdraw(self):                         #''
     temp=input('Enter your pin')
     if temp==self.__pin:
        amount=int(input('Enter the Amount'))
        if amount< self.__balance :
              self.__balance=self.__balance-amount
              print('Opration Successful')
        else:
              print('insufficient funds')
     else:
      print('invalid pin')

  def check_balance(self):                 #''
     temp=input('Enter your pin')
     if temp==self.__pin:
      print(self.__balance)

     else:
      print("invalid pin ")

# %%
sbi=ATM()
# Out:
#         Hello how would you like to pocecced?
#         1.Enter 1 to Create pin
#         2.Enter 2 to deposit
#         3.Enter 3 to withdraw
#         4.Enter 4 to check Balance
#         5.Enter 5 to exit
#
#
#
#        1
# Enter your pin 1234
# Pin set Successfully

# %%
ATM.get_counter()
# Out:
# 2

# %%
sbi=ATM()
# Out:
#         Hello how would you like to pocecced?
#         1.Enter 1 to Create pin
#         2.Enter 2 to deposit
#         3.Enter 3 to withdraw
#         4.Enter 4 to check Balance
#         5.Enter 5 to exit
#
#
#
#        1
# Enter your pin 2345
# Pin set Successfully

# %%
ATM.get_counter()
# Out:
# 3

# %%
"""class phone:

  def __init__(self,price,brand,camera):
  print('inside phone constructor')

  self.price=price
  self.brand=brand
  self.camera=camera


class smartpone(phone):
  pass


s=smartphone(20000,apple,13)"""
# Out:
# "class phone:\n\n  def __init__(self,price,brand,camera):\n  print('inside phone constructor')\n\n  self.price=price\n  self.brand=brand\n  self.camera=camera\n\n\nclass smartpone(phone):\n  pass\n\n\ns=smartphone(20000,apple,13)"
